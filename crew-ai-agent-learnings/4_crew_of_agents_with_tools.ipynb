# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM

llm = LLM(
    model = "gemini/gemini-2.0-flash",
    temperature = 0.1
)

# %%
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 from crewai import Agent, Task, Crew
# ----> 2 from crewai_tools import SerperDevTool
#       4 research_agent = Agent(
#       5     role="Research Specialist",
#       6     goal="Research interesting facts about the topic: {topic}",
#    (...)      9     llm=llm
#      10 )
#      12 writer_agent = Agent(
#      13     role="Creative Writer",
#      14     goal="Write a short blog summary using the research",
#    (...)     17     verbose=True,
#      18 )
#
# ImportError: cannot import name 'SerperDevTool' from 'crewai_tools' (c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai_tools\__init__.py)

# %%
research_task = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

writer_task = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[research_task],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[research_task, writer_task],
    verbose=True
)

result = crew.kickoff(inputs={"topic":"The future of ML, DL, NLP"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 816f8a52-f617-4f60-a4fe-4b8b2c75b7cc                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of ML, DL, NLP.                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────────── LLM Error ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ LLM Call Failed                                                                                             │
# │  Error: litellm.AuthenticationError: geminiException - {                                                        │
# │    "error": {                                                                                                   │
# │      "code": 400,                                                                                               │
# │      "message": "API key not valid. Please pass a valid API key.",                                              │
# │      "status": "INVALID_ARGUMENT",                                                                              │
# │      "details": [                                                                                               │
# │        {                                                                                                        │
# │          "@type": "type.googleapis.com/google.rpc.ErrorInfo",                                                   │
# │          "reason": "API_KEY_INVALID",                                                                           │
# │          "domain": "googleapis.com",                                                                            │
# │          "metadata": {                                                                                          │
# │            "service": "generativelanguage.googleapis.com"                                                       │
# │          }                                                                                                      │
# │        },                                                                                                       │
# │        {                                                                                                        │
# │          "@type": "type.googleapis.com/google.rpc.LocalizedMessage",                                            │
# │          "locale": "en-US",                                                                                     │
# │          "message": "API key not valid. Please pass a valid API key."                                           │
# │        }                                                                                                        │
# │      ]                                                                                                          │
# │    }                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── Task Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: 2a0187c9-5594-45bd-a5c6-f00f0a008893                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: 816f8a52-f617-4f60-a4fe-4b8b2c75b7cc                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output:                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py:1890, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    1889 try:
# -> 1890     response = client.post(url=url, headers=headers, json=data)  # type: ignore
#    1891     response.raise_for_status()
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:780, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     779     setattr(e, "status_code", e.response.status_code)
# --> 780     raise e
#     781 except Exception as e:
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:762, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     761 response = self.client.send(req, stream=stream)
# --> 762 response.raise_for_status()
#     763 return response
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key=None'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
#
# During handling of the above exception, another exception occurred:
#
# VertexAIError                             Traceback (most recent call last)
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\main.py:2606, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    2605     new_params = deepcopy(optional_params)
# -> 2606     response = vertex_chat_completion.completion(  # type: ignore
#    2607         model=model,
#    2608         messages=messages,
#    2609         model_response=model_response,
#    2610         print_verbose=print_verbose,
#    2611         optional_params=new_params,
#    2612         litellm_params=litellm_params,  # type: ignore
#    2613         logger_fn=logger_fn,
#    2614         encoding=encoding,
#    2615         vertex_location=vertex_ai_location,
#    2616         vertex_project=vertex_ai_project,
#    2617         vertex_credentials=vertex_credentials,
#    2618         gemini_api_key=gemini_api_key,
#    2619         logging_obj=logging,
#    2620         acompletion=acompletion,
#    2621         timeout=timeout,
#    2622         custom_llm_provider=custom_llm_provider,
#    2623         client=client,
#    2624         api_base=api_base,
#    2625         extra_headers=extra_headers,
#    2626     )
#    2628 elif custom_llm_provider == "vertex_ai":
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py:1894, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    1893     error_code = err.response.status_code
# -> 1894     raise VertexAIError(
#    1895         status_code=error_code,
#    1896         message=err.response.text,
#    1897         headers=err.response.headers,
#    1898     )
#    1899 except httpx.TimeoutException:
#
# VertexAIError: {
#   "error": {
#     "code": 400,
#     "message": "API key not valid. Please pass a valid API key.",
#     "status": "INVALID_ARGUMENT",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "API_KEY_INVALID",
#         "domain": "googleapis.com",
#         "metadata": {
#           "service": "generativelanguage.googleapis.com"
#         }
#       },
#       {
#         "@type": "type.googleapis.com/google.rpc.LocalizedMessage",
#         "locale": "en-US",
#         "message": "API key not valid. Please pass a valid API key."
#       }
#     ]
#   }
# }
#
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[13], line 7
#       1 crew = Crew(
#       2     agents=[research_agent, writer_agent],
#       3     tasks=[research_task, writer_task],
#       4     verbose=True
#       5 )
# ----> 7 result = crew.kickoff(inputs={"topic":"The future of ML, DL, NLP"})
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\crew.py:661, in Crew.kickoff(self, inputs)
#     658     self._handle_crew_planning()
#     660 if self.process == Process.sequential:
# --> 661     result = self._run_sequential_process()
#     662 elif self.process == Process.hierarchical:
#     663     result = self._run_hierarchical_process()
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\crew.py:772, in Crew._run_sequential_process(self)
#     770 def _run_sequential_process(self) -> CrewOutput:
#     771     """Executes tasks sequentially and returns the final output."""
# --> 772     return self._execute_tasks(self.tasks)
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\crew.py:875, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     872     futures.clear()
#     874 context = self._get_context(task, task_outputs)
# --> 875 task_output = task.execute_sync(
#     876     agent=agent_to_use,
#     877     context=context,
#     878     tools=cast(List[BaseTool], tools_for_task),
#     879 )
#     880 task_outputs.append(task_output)
#     881 self._process_task_result(task, task_output)
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\task.py:382, in Task.execute_sync(self, agent, context, tools)
#     375 def execute_sync(
#     376     self,
#     377     agent: Optional[BaseAgent] = None,
#     378     context: Optional[str] = None,
#     379     tools: Optional[List[BaseTool]] = None,
#     380 ) -> TaskOutput:
#     381     """Execute the task synchronously."""
# --> 382     return self._execute_core(agent, context, tools)
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\task.py:530, in Task._execute_core(self, agent, context, tools)
#     528 self.end_time = datetime.datetime.now()
#     529 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 530 raise e
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\task.py:446, in Task._execute_core(self, agent, context, tools)
#     444 self.processed_by_agents.add(agent.role)
#     445 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 446 result = agent.execute_task(
#     447     task=self,
#     448     context=context,
#     449     tools=tools,
#     450 )
#     452 pydantic_output, json_output = self._export_output(result)
#     453 task_output = TaskOutput(
#     454     name=self.name or self.description,
#     455     description=self.description,
#    (...)    461     output_format=self._get_output_format(),
#     462 )
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\agent.py:475, in Agent.execute_task(self, task, context, tools)
#     465 if e.__class__.__module__.startswith("litellm"):
#     466     # Do not retry on litellm errors
#     467     crewai_event_bus.emit(
#     468         self,
#     469         event=AgentExecutionErrorEvent(
#    (...)    473         ),
#     474     )
# --> 475     raise e
#     476 self._times_executed += 1
#     477 if self._times_executed > self.max_retry_limit:
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\agent.py:451, in Agent.execute_task(self, task, context, tools)
#     447         result = self._execute_with_timeout(
#     448             task_prompt, task, self.max_execution_time
#     449         )
#     450     else:
# --> 451         result = self._execute_without_timeout(task_prompt, task)
#     453 except TimeoutError as e:
#     454     # Propagate TimeoutError without retry
#     455     crewai_event_bus.emit(
#     456         self,
#     457         event=AgentExecutionErrorEvent(
#    (...)    461         ),
#     462     )
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\agent.py:547, in Agent._execute_without_timeout(self, task_prompt, task)
#     537 def _execute_without_timeout(self, task_prompt: str, task: Task) -> str:
#     538     """Execute a task without a timeout.
#     539
#     540     Args:
#    (...)    545         The output of the agent.
#     546     """
# --> 547     return self.agent_executor.invoke(
#     548         {
#     549             "input": task_prompt,
#     550             "tool_names": self.agent_executor.tools_names,
#     551             "tools": self.agent_executor.tools_description,
#     552             "ask_for_human_input": task.human_input,
#     553         }
#     554     )["output"]
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\agents\crew_agent_executor.py:114, in CrewAgentExecutor.invoke(self, inputs)
#     111 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     113 try:
# --> 114     formatted_answer = self._invoke_loop()
#     115 except AssertionError:
#     116     self._printer.print(
#     117         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     118         color="red",
#     119     )
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\agents\crew_agent_executor.py:208, in CrewAgentExecutor._invoke_loop(self)
#     205 except Exception as e:
#     206     if e.__class__.__module__.startswith("litellm"):
#     207         # Do not retry on litellm errors
# --> 208         raise e
#     209     if is_context_length_exceeded(e):
#     210         handle_context_length(
#     211             respect_context_window=self.respect_context_window,
#     212             printer=self._printer,
#    (...)    216             i18n=self._i18n,
#     217         )
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\agents\crew_agent_executor.py:154, in CrewAgentExecutor._invoke_loop(self)
#     143     formatted_answer = handle_max_iterations_exceeded(
#     144         formatted_answer,
#     145         printer=self._printer,
#    (...)    149         callbacks=self.callbacks,
#     150     )
#     152 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 154 answer = get_llm_response(
#     155     llm=self.llm,
#     156     messages=self.messages,
#     157     callbacks=self.callbacks,
#     158     printer=self._printer,
#     159     from_task=self.task
#     160 )
#     161 formatted_answer = process_llm_response(answer, self.use_stop_words)
#     163 if isinstance(formatted_answer, AgentAction):
#     164     # Extract agent fingerprint if available
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\utilities\agent_utils.py:160, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent)
#     153     answer = llm.call(
#     154         messages,
#     155         callbacks=callbacks,
#     156         from_task=from_task,
#     157         from_agent=from_agent,
#     158     )
#     159 except Exception as e:
# --> 160     raise e
#     161 if not answer:
#     162     printer.print(
#     163         content="Received None or empty response from LLM call.",
#     164         color="red",
#     165     )
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\utilities\agent_utils.py:153, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent)
#     151 """Call the LLM and return the response, handling any invalid responses."""
#     152 try:
# --> 153     answer = llm.call(
#     154         messages,
#     155         callbacks=callbacks,
#     156         from_task=from_task,
#     157         from_agent=from_agent,
#     158     )
#     159 except Exception as e:
#     160     raise e
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\llm.py:1030, in LLM.call(self, messages, tools, callbacks, available_functions, from_task, from_agent)
#    1026         return self._handle_streaming_response(
#    1027             params, callbacks, available_functions, from_task, from_agent
#    1028         )
#    1029     else:
# -> 1030         return self._handle_non_streaming_response(
#    1031             params, callbacks, available_functions, from_task, from_agent
#    1032         )
#    1034 except LLMContextLengthExceededException:
#    1035     # Re-raise LLMContextLengthExceededException as it should be handled
#    1036     # by the CrewAgentExecutor._invoke_loop method, which can then decide
#    1037     # whether to summarize the content or abort based on the respect_context_window flag
#    1038     raise
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\crewai\llm.py:813, in LLM._handle_non_streaming_response(self, params, callbacks, available_functions, from_task, from_agent)
#     807 # --- 1) Make the completion call
#     808 try:
#     809     # Attempt to make the completion call, but catch context window errors
#     810     # and convert them to our own exception type for consistent handling
#     811     # across the codebase. This allows CrewAgentExecutor to handle context
#     812     # length issues appropriately.
# --> 813     response = litellm.completion(**params)
#     815 except ContextWindowExceededError as e:
#     816     # Convert litellm's context window error to our own exception type
#     817     # for consistent handling in the rest of the codebase
#     818     raise LLMContextLengthExceededException(str(e))
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\utils.py:1330, in client.<locals>.wrapper(*args, **kwargs)
#    1326 if logging_obj:
#    1327     logging_obj.failure_handler(
#    1328         e, traceback_exception, start_time, end_time
#    1329     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1330 raise e
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\utils.py:1205, in client.<locals>.wrapper(*args, **kwargs)
#    1203         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1204 # MODEL CALL
# -> 1205 result = original_function(*args, **kwargs)
#    1206 end_time = datetime.datetime.now()
#    1207 if _is_streaming_request(
#    1208     kwargs=kwargs,
#    1209     call_type=call_type,
#    1210 ):
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\main.py:3427, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3424     return response
#    3425 except Exception as e:
#    3426     ## Map to OpenAI Exception
# -> 3427     raise exception_type(
#    3428         model=model,
#    3429         custom_llm_provider=custom_llm_provider,
#    3430         original_exception=e,
#    3431         completion_kwargs=args,
#    3432         extra_kwargs=kwargs,
#    3433     )
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2301, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2299 if exception_mapping_worked:
#    2300     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2301     raise e
#    2302 else:
#    2303     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File c:\Users\pilot\AppData\Local\Programs\Python\Python313\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:1218, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    1216 elif "API key not valid." in error_str:
#    1217     exception_mapping_worked = True
# -> 1218     raise AuthenticationError(
#    1219         message=f"{custom_llm_provider}Exception - {error_str}",
#    1220         model=model,
#    1221         llm_provider=custom_llm_provider,
#    1222         litellm_debug_info=extra_information,
#    1223     )
#    1224 elif "403" in error_str:
#    1225     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: geminiException - {
#   "error": {
#     "code": 400,
#     "message": "API key not valid. Please pass a valid API key.",
#     "status": "INVALID_ARGUMENT",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "API_KEY_INVALID",
#         "domain": "googleapis.com",
#         "metadata": {
#           "service": "generativelanguage.googleapis.com"
#         }
#       },
#       {
#         "@type": "type.googleapis.com/google.rpc.LocalizedMessage",
#         "locale": "en-US",
#         "message": "API key not valid. Please pass a valid API key."
#       }
#     ]
#   }
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\stack_data\core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\stack_data\utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~\AppData\Roaming\Python\Python313\site-packages\stack_data\core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File ~\AppData\Roaming\Python\Python313\site-packages\stack_data\utils.py:166, in _pygmented_with_ranges(formatter, code, ranges)
#     164 lexer = MyLexer(stripnl=False)
#     165 try:
# --> 166     highlighted = pygments.highlight(code, lexer, formatter)
#     167 except Exception:
#     168     # When pygments fails, prefer code without highlighting over crashing
#     169     highlighted = code
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pygments\__init__.py:82, in highlight(code, lexer, formatter, outfile)
#      77 def highlight(code, lexer, formatter, outfile=None):
#      78     """
#      79     This is the most high-level highlighting function. It combines `lex` and
#      80     `format` in one function.
#      81     """
# ---> 82     return format(lex(code, lexer), formatter, outfile)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pygments\__init__.py:64, in format(tokens, formatter, outfile)
#      62 if not outfile:
#      63     realoutfile = getattr(formatter, 'encoding', None) and BytesIO() or StringIO()
# ---> 64     formatter.format(tokens, realoutfile)
#      65     return realoutfile.getvalue()
#      66 else:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pygments\formatters\terminal256.py:250, in Terminal256Formatter.format(self, tokensource, outfile)
#     249 def format(self, tokensource, outfile):
# --> 250     return Formatter.format(self, tokensource, outfile)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pygments\formatter.py:124, in Formatter.format(self, tokensource, outfile)
#     121 if self.encoding:
#     122     # wrap the outfile in a StreamWriter
#     123     outfile = codecs.lookup(self.encoding)[3](outfile)
# --> 124 return self.format_unencoded(tokensource, outfile)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pygments\formatters\terminal256.py:256, in Terminal256Formatter.format_unencoded(self, tokensource, outfile)
#     253 if self.linenos:
#     254     self._write_lineno(outfile)
# --> 256 for ttype, value in tokensource:
#     257     not_found = True
#     258     while ttype and not_found:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\stack_data\utils.py:158, in _pygmented_with_ranges.<locals>.MyLexer.get_tokens(self, text)
#     156 def get_tokens(self, text):
#     157     length = 0
# --> 158     for ttype, value in super().get_tokens(text):
#     159         if any(start <= length < end for start, end in ranges):
#     160             ttype = ttype.ExecutingNode
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pygments\lexer.py:270, in Lexer.get_tokens.<locals>.streamer()
#     269 def streamer():
# --> 270     for _, t, v in self.get_tokens_unprocessed(text):
#     271         yield t, v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pygments\lexer.py:713, in RegexLexer.get_tokens_unprocessed(self, text, stack)
#     711 for rexmatch, action, new_state in statetokens:
#     712     m = rexmatch(text, pos)
# --> 713     if m:
#     714         if action is not None:
#     715             if type(action) is _TokenType:
#
# KeyboardInterrupt:
